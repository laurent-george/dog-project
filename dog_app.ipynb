# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from keras.callbacks import ModelCheckpoint  


# don't allow full gpu memory if not required
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session

config = tf.ConfigProto()
config.gpu_options.allow_growth = True

set_session(tf.Session(config=config))
# Out:
# Using TensorFlow backend.

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("dogImages/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %%
dogs_preview = dict()

for num, target in enumerate(train_targets):
    breed = dog_names[np.argmax(target)]
    if breed in dogs_preview:
        # we add a picture only if this breed has not been seen yet
        continue
    dogs_preview[breed] = train_files[num]

# %%
dogs_preview['Dalmatian']
# Out:
# 'dogImages/train/057.Dalmatian/Dalmatian_04054.jpg'

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[3])
#img = cv2.imread(human_files[5])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.

def count_detection(images, detector_func=face_detector):
    """
    return the number of detection
    Arguments:
        images: a list of images array
        detector_func: a function that return True if a detection occurs (e.g human_face_decetor)
    """
    counter = 0
    for image in images:
        if detector_func(image):
            counter += 1
    return counter


face_detection_percentage_in_humans_db = count_detection(human_files_short, face_detector) / len(human_files_short)
face_detection_percentage_in_dog_db = count_detection(dog_files_short, face_detector) / len(dog_files_short)

print("Percentage of the first 100 images in human_files that have a detected human face is {:.1%}".format(face_detection_percentage_in_humans_db))
print("Percentage of the first 100 images in dog_files that have a detected human face is {:.1%}".format(face_detection_percentage_in_dog_db))
# Out:
# Percentage of the first 100 images in human_files that have a detected human face is 99.0%
# Percentage of the first 100 images in dog_files that have a detected human face is 11.0%

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %% [markdown]
# Concerning the first part of the question: "If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?"
#
#     Opencv also provide face a haar cascade model trained to detect profile face in the file https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_profileface.xml
#
# Combining the two models should allows to detect more faces in case the user is not in front of the camera (profile).
#
# But this may not suffice to tackle all the faces, let's try that
#
# Here we display the face that are not detected as face by both detector

# %%
front_face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')
profile_face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_profileface.xml')
def face_detector_opencv_improved(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    profile_faces = profile_face_cascade.detectMultiScale(gray)
    return len(faces) + len(profile_faces) > 0

# There are still image that we don't get using the mix of the two classifiers
for num, img_path in enumerate(human_files[0:1000]):
    if face_detector(img_path) == 0 and face_detector_opencv_improved(img_path) == 0:
        # we display image if face has not been detected
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.imshow(img)
        plt.title('image {}'.format(num))
        plt.show()

# %%
# Let's look at the accuracy on the full human dataset of lfw
#accuracy_default_detector = count_detection(human_files, face_detector) / len(human_files)
#accuracy_profile_and_front_detector = count_detection(human_files, face_detector_opencv_improved) / len(human_files)

#print("Accuracy of default detector {:.1%}".format(accuracy_default_detector))
#print("Accuracy of improved detector (profile and front) {:.1%}".format(accuracy_profile_and_front_detector))

# %%
# we have a small improvement on the lfw detection as expected

# %%
# Now let's look at the results of the two detector on dog data
#dog_files = train_files
#old_detector_for_dog = count_detection(dog_files, face_detector) / len(dog_files)
#new_detector_for_dog = count_detection(dog_files, face_detector_opencv_improved) / len(dog_files)
##
#print("Old  {}  vs new {}  (less is better) ".format(old_detector_for_dog, new_detector_for_dog))

# %% [markdown]
# We see that this approach unfortunately increase the number of human face detection in dog dataset.
#
# An other approach will be to have a face detector based on deep learning.

# %% [markdown]
# ## (Optional) TODO: Report the performance of another
# ## face detection algorithm on the LFW dataset
# ### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

# We reuse the count_detection function that we defined above

dog_in_faces_db = count_detection(human_files_short, dog_detector) / len(human_files_short)
dog_in_dogs_db = count_detection(dog_files_short, dog_detector) / len(dog_files_short)

print("Percentage of the first 100 images in human_files that have a detected dog face is {:.1%}".format(dog_in_faces_db))
print("Percentage of the first 100 images in dog_files that have a detected dog face is {:.1%}".format(dog_in_dogs_db))
# Out:
# Percentage of the first 100 images in human_files that have a detected dog face is 0.0%
# Percentage of the first 100 images in dog_files that have a detected dog face is 100.0%

# %% [markdown]
# # That's is pretty impressive !

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [00:38<00:00, 174.85it/s]
# 100%|██████████| 835/835 [00:04<00:00, 196.39it/s]
# 100%|██████████| 836/836 [00:04<00:00, 197.08it/s]

# %%
# thanks to tqdm we have a really nice progress bar, thanks udacity :D

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

dropout_rate = 0.5
model = Sequential()

### TODO: Define your architecture.

# as we works with images, using a fully-convolutional neural network seems the way to go (moreover it's in the project name)

# we choose to use elu here as activation function

# we use only 64 features on the first convolution, it should allows to extract all kind of features like edges etc
# in VGG it's the kind of first level that is used, so I guess it sufficient for our problem

# we also use padding same to preserve the size of the image
# this give use : (64+ 64*9*3) parameters

model.add(Conv2D(64, (3, 3), input_shape=(224, 224, 3), activation='elu', padding='same'))

# we then redo that in order to extract more high level features but we don't do any maxpooling between this two layer yet
# this time we have a lot more parameters, because the depth of input is 64: 
# so we have (64+64*9*64) parameters
model.add(Conv2D(64, (3, 3), padding='same', activation='elu'))

# we use maxpooling, it allows to summarize the information of neighboored pixels, it could also help to redducce computation time
model.add(MaxPooling2D((2,2), strides=(2,2)))
model.add(Conv2D(64, (3, 3), padding='same', activation='elu'))

model.add(MaxPooling2D((2,2), strides=(2,2)))
model.add(Conv2D(64, (3, 3), padding='same', activation='elu'))

model.add(MaxPooling2D((2,2), strides=(2,2)))
model.add(Conv2D(64, (3, 3), padding='same', activation='elu'))

model.add(MaxPooling2D((2,2), strides=(2,2)))
model.add(Conv2D(64, (3, 3), padding='same', activation='elu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(GlobalAveragePooling2D())

# in order to redduce overfitting, we add a dropout layer here
model.add(Dropout(dropout_rate))

## finally we use a fully connected layer followed by softmax layer to get the probability of each class
model.add(Dense(units=len(dog_names), activation='softmax'))

model.summary()



#model.add(Flatten())
# Then the fully connected layers:
#model.add(Dense(units=len(dog_names), activation='elu'))
#model.add(Dense(units=len(dog_names), activation='elu'))
#model.add(Dropout(0.5))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 133)               8645
# =================================================================
# Total params: 195,077
# Trainable params: 195,077
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 100

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=64, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 3.3481 - acc: 0.2048Epoch 00000: val_loss improved from inf to 3.34559, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 30s - loss: 3.3486 - acc: 0.2048 - val_loss: 3.3456 - val_acc: 0.2263
# Epoch 2/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 3.2034 - acc: 0.2218Epoch 00001: val_loss improved from 3.34559 to 3.03490, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 29s - loss: 3.2031 - acc: 0.2216 - val_loss: 3.0349 - val_acc: 0.2563
# Epoch 3/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 3.0625 - acc: 0.2423Epoch 00002: val_loss did not improve
# 6680/6680 [==============================] - 29s - loss: 3.0634 - acc: 0.2422 - val_loss: 3.0853 - val_acc: 0.2527
# Epoch 4/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.9862 - acc: 0.2605Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 28s - loss: 2.9876 - acc: 0.2605 - val_loss: 3.0388 - val_acc: 0.2611
# Epoch 5/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.9096 - acc: 0.2730Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 28s - loss: 2.9091 - acc: 0.2729 - val_loss: 3.0556 - val_acc: 0.2335
# Epoch 6/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.8375 - acc: 0.2880Epoch 00005: val_loss improved from 3.03490 to 2.95431, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 28s - loss: 2.8379 - acc: 0.2877 - val_loss: 2.9543 - val_acc: 0.2743
# Epoch 7/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.7703 - acc: 0.2993Epoch 00006: val_loss improved from 2.95431 to 2.89000, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 28s - loss: 2.7692 - acc: 0.2991 - val_loss: 2.8900 - val_acc: 0.2862
# Epoch 8/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.7235 - acc: 0.3036Epoch 00007: val_loss improved from 2.89000 to 2.88548, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 28s - loss: 2.7237 - acc: 0.3034 - val_loss: 2.8855 - val_acc: 0.3006
# Epoch 9/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.6567 - acc: 0.3158Epoch 00008: val_loss improved from 2.88548 to 2.62869, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 28s - loss: 2.6546 - acc: 0.3166 - val_loss: 2.6287 - val_acc: 0.3317
# Epoch 10/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.5997 - acc: 0.3308Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 28s - loss: 2.6007 - acc: 0.3307 - val_loss: 2.8236 - val_acc: 0.2814
# Epoch 11/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.5590 - acc: 0.3454Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 28s - loss: 2.5610 - acc: 0.3448 - val_loss: 2.8353 - val_acc: 0.2862
# Epoch 12/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.5209 - acc: 0.3529Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 28s - loss: 2.5200 - acc: 0.3536 - val_loss: 2.7731 - val_acc: 0.3102
# Epoch 13/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.4739 - acc: 0.3625Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 29s - loss: 2.4755 - acc: 0.3623 - val_loss: 2.6679 - val_acc: 0.3329
# Epoch 14/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.4174 - acc: 0.3727Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 28s - loss: 2.4182 - acc: 0.3720 - val_loss: 2.8639 - val_acc: 0.2874
# Epoch 15/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.3696 - acc: 0.3803Epoch 00014: val_loss improved from 2.62869 to 2.62374, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 28s - loss: 2.3682 - acc: 0.3802 - val_loss: 2.6237 - val_acc: 0.3365
# Epoch 16/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.3439 - acc: 0.3867Epoch 00015: val_loss improved from 2.62374 to 2.54136, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 28s - loss: 2.3442 - acc: 0.3868 - val_loss: 2.5414 - val_acc: 0.3533
# Epoch 17/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.2626 - acc: 0.3938Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 28s - loss: 2.2638 - acc: 0.3934 - val_loss: 2.6489 - val_acc: 0.3162
# Epoch 18/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.2253 - acc: 0.4094Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 28s - loss: 2.2265 - acc: 0.4093 - val_loss: 2.9213 - val_acc: 0.2862
# Epoch 19/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.2325 - acc: 0.4062Epoch 00018: val_loss improved from 2.54136 to 2.50249, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 28s - loss: 2.2336 - acc: 0.4061 - val_loss: 2.5025 - val_acc: 0.3509
# Epoch 20/100
# 6656/6680 [============================>.] - ETA: 0s - loss: 2.1523 - acc: 0.4217Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 28s - loss: 2.1525 - acc: 0.4217 - val_loss: 2.6124 - val_acc: 0.3353
# Epoch 21/100
# 1856/6680 [=======>......................] - ETA: 20s - loss: 2.0407 - acc: 0.4445
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-5e26712728e9> in <module>()
#      12 model.fit(train_tensors, train_targets,
#      13           validation_data=(valid_tensors, valid_targets),
# ---> 14           epochs=epochs, batch_size=64, callbacks=[checkpointer], verbose=1)
#
# /home/lgeorge/anaconda3/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     865                               class_weight=class_weight,
#     866                               sample_weight=sample_weight,
# --> 867                               initial_epoch=initial_epoch)
#     868
#     869     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /home/lgeorge/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1596                               initial_epoch=initial_epoch,
#    1597                               steps_per_epoch=steps_per_epoch,
# -> 1598                               validation_steps=validation_steps)
#    1599
#    1600     def evaluate(self, x, y,
#
# /home/lgeorge/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1181                     batch_logs['size'] = len(batch_ids)
#    1182                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1183                     outs = f(ins_batch)
#    1184                     if not isinstance(outs, list):
#    1185                         outs = [outs]
#
# /home/lgeorge/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2271         updated = session.run(self.outputs + [self.updates_op],
#    2272                               feed_dict=feed_dict,
# -> 2273                               **self.session_kwargs)
#    2274         return updated[:len(self.outputs)]
#    2275
#
# /home/lgeorge/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/lgeorge/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /home/lgeorge/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/lgeorge/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /home/lgeorge/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)

# first training without dropout, 80 % on training data, but accuracy only 25 % on testing data

# best test accuracy with dropout of 0.25 -> test accuracy 34% , learning stopped at epoch 35
# dropout = 0.5 -> test accuracy 34.569, learning stop at epoch 47
# Out:
# Test accuracy: 33.8517%

# %% [markdown]
# Our test accuracy is greater than 1 % ( we have 34%), which seems to be quite good after training only on such small dataset from scratch.

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 12.6192 - acc: 0.1061Epoch 00000: val_loss improved from inf to 11.23925, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 12.6098 - acc: 0.1069 - val_loss: 11.2392 - val_acc: 0.1856
# Epoch 2/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 10.7201 - acc: 0.2428Epoch 00001: val_loss improved from 11.23925 to 10.54733, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 10.7042 - acc: 0.2443 - val_loss: 10.5473 - val_acc: 0.2611
# Epoch 3/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 10.1007 - acc: 0.3063Epoch 00002: val_loss improved from 10.54733 to 10.38791, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 10.0972 - acc: 0.3067 - val_loss: 10.3879 - val_acc: 0.2743
# Epoch 4/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 9.6991 - acc: 0.3462Epoch 00003: val_loss improved from 10.38791 to 10.05932, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 9.6961 - acc: 0.3463 - val_loss: 10.0593 - val_acc: 0.3018
# Epoch 5/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 9.4903 - acc: 0.3733Epoch 00004: val_loss improved from 10.05932 to 9.87053, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 9.4944 - acc: 0.3729 - val_loss: 9.8705 - val_acc: 0.3030
# Epoch 6/20
# 6440/6680 [===========================>..] - ETA: 0s - loss: 9.1004 - acc: 0.3910Epoch 00005: val_loss improved from 9.87053 to 9.51369, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 9.1103 - acc: 0.3903 - val_loss: 9.5137 - val_acc: 0.3305
# Epoch 7/20
# 6480/6680 [============================>.] - ETA: 0s - loss: 8.9125 - acc: 0.4199Epoch 00006: val_loss improved from 9.51369 to 9.44461, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 8.9153 - acc: 0.4199 - val_loss: 9.4446 - val_acc: 0.3509
# Epoch 8/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 8.8304 - acc: 0.4292Epoch 00007: val_loss improved from 9.44461 to 9.39563, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 8.8327 - acc: 0.4290 - val_loss: 9.3956 - val_acc: 0.3545
# Epoch 9/20
# 6480/6680 [============================>.] - ETA: 0s - loss: 8.7522 - acc: 0.4395Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 8.7665 - acc: 0.4383 - val_loss: 9.4224 - val_acc: 0.3545
# Epoch 10/20
# 6380/6680 [===========================>..] - ETA: 0s - loss: 8.7517 - acc: 0.4433Epoch 00009: val_loss improved from 9.39563 to 9.35761, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 8.7206 - acc: 0.4443 - val_loss: 9.3576 - val_acc: 0.3509
# Epoch 11/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 8.5527 - acc: 0.4474Epoch 00010: val_loss improved from 9.35761 to 9.06734, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 8.5350 - acc: 0.4479 - val_loss: 9.0673 - val_acc: 0.3605
# Epoch 12/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 8.1347 - acc: 0.4744Epoch 00011: val_loss improved from 9.06734 to 8.80716, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 8.1456 - acc: 0.4740 - val_loss: 8.8072 - val_acc: 0.3856
# Epoch 13/20
# 6500/6680 [============================>.] - ETA: 0s - loss: 8.0685 - acc: 0.4883Epoch 00012: val_loss improved from 8.80716 to 8.72854, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 8.0668 - acc: 0.4883 - val_loss: 8.7285 - val_acc: 0.3952
# Epoch 14/20
# 6340/6680 [===========================>..] - ETA: 0s - loss: 7.9834 - acc: 0.4987Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 8.0335 - acc: 0.4958 - val_loss: 8.7703 - val_acc: 0.3916
# Epoch 15/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 7.9692 - acc: 0.4919Epoch 00014: val_loss improved from 8.72854 to 8.58881, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 7.9548 - acc: 0.4927 - val_loss: 8.5888 - val_acc: 0.3928
# Epoch 16/20
# 6400/6680 [===========================>..] - ETA: 0s - loss: 7.7610 - acc: 0.5050Epoch 00015: val_loss improved from 8.58881 to 8.48478, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 7.7494 - acc: 0.5055 - val_loss: 8.4848 - val_acc: 0.4048
# Epoch 17/20
# 6460/6680 [============================>.] - ETA: 0s - loss: 7.6867 - acc: 0.5153Epoch 00016: val_loss improved from 8.48478 to 8.44056, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 7.6951 - acc: 0.5148 - val_loss: 8.4406 - val_acc: 0.4096
# Epoch 18/20
# 6500/6680 [============================>.] - ETA: 0s - loss: 7.6514 - acc: 0.5188Epoch 00017: val_loss improved from 8.44056 to 8.29011, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 7.6584 - acc: 0.5180 - val_loss: 8.2901 - val_acc: 0.4287
# Epoch 19/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 7.5013 - acc: 0.5291Epoch 00018: val_loss improved from 8.29011 to 8.27993, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 7.5031 - acc: 0.5290 - val_loss: 8.2799 - val_acc: 0.4323
# Epoch 20/20
# 6280/6680 [===========================>..] - ETA: 0s - loss: 7.5264 - acc: 0.5303Epoch 00019: val_loss improved from 8.27993 to 8.19660, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 7.4901 - acc: 0.5323 - val_loss: 8.1966 - val_acc: 0.4395

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 41.8660%

# %% [markdown]
# Using VGG pretrained model, the accuracy is better than the accuracy that we get with the model trained from scratch.
# Moreover the training is a lot faster as we freeze all the layers except the new one at the end of the network.
#
# Fine tunning a model is really relevant here:
# - our dataset is small
# - imagenet dataset has a lot of dogs in it -> thus features learned on imagenet provide good feature to detect dog (and fine tuning on our data show that this feature are relevant to predict breed too).

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.  Pick one of the above architectures, download the corresponding bottleneck features, and store the downloaded file in the `bottleneck_features/` folder in the repository.
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %% [markdown]
# In the following we are going to compare Resnet50 and Xception. We also tried to use data augmentation but it does not improve the best accuracy obtained here.

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.


# we use dictionary to store features, train, valid, test for each network, it allows to iterate in a loop for instance
train = {}
valid = {}
test = {}
bottleneck_features = {}

networks = ['Resnet50', 'Xception']
for network in networks:
    bottleneck_features = np.load('bottleneck_features/Dog{}Data.npz'.format(network))
    train[network] = bottleneck_features['train']
    valid[network] = bottleneck_features['valid']
    test[network] = bottleneck_features['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__

# %%
### TODO: Define your architecture.
import keras
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
# we use similar approach as before, taking the pretrained layer and adding a global average and a fully connected with a softmax activation in order to compute a 
# a 'probability' for each class (i.e for each dog breed)

rate = 0.3
my_models = {}
for network in networks:
    my_models[network] = Sequential()
    my_model = my_models[network]
    my_model.add(Dropout(rate, input_shape=train[network].shape[1:]))
    my_model.add(GlobalAveragePooling2D(input_shape=train[network].shape[1:]))
    my_model.add(Dropout(rate))
    #my_model.add(Dense(1000, activation='elu'))
    #my_model.add(Dropout(rate))
    my_model.add(Dense(133, activation='softmax'))
    print("model based on pre-trained network {}".format(network))
    my_model.summary()
    print('\n')
# Out:
# model based on pre-trained network Resnet50
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout_45 (Dropout)         (None, 1, 1, 2048)        0
# _________________________________________________________________
# global_average_pooling2d_25  (None, 2048)              0
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_49 (Dense)             (None, 133)               272517
# =================================================================
# Total params: 272,517
# Trainable params: 272,517
# Non-trainable params: 0
# _________________________________________________________________
#
#
# model based on pre-trained network Xception
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout_47 (Dropout)         (None, 7, 7, 2048)        0
# _________________________________________________________________
# global_average_pooling2d_26  (None, 2048)              0
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_50 (Dense)             (None, 133)               272517
# =================================================================
# Total params: 272,517
# Trainable params: 272,517
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.
for model_name, model in my_models.items():
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: Train the model.

for network_name, model in my_models.items():
    print("fine tunning {}".format(network_name))
    checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.{}.hdf5'.format(network_name),  verbose=1, save_best_only=True)

    model.fit(train[network_name], train_targets, 
          validation_data=(valid[network_name], valid_targets),
          epochs=50, batch_size=512, callbacks=[checkpointer], verbose=1)
# Out:
# fine tunning Resnet50
# Train on 6680 samples, validate on 835 samples
# Epoch 1/50
# 6144/6680 [==========================>...] - ETA: 0s - loss: 0.1531 - acc: 0.9637Epoch 00000: val_loss improved from inf to 0.54494, saving model to saved_models/weights.best.Resnet50.hdf5
# 6680/6680 [==============================] - 0s - loss: 0.1529 - acc: 0.9635 - val_loss: 0.5449 - val_acc: 0.8180
# Epoch 2/50
# 6144/6680 [==========================>...] - ETA: 0s - loss: 0.1439 - acc: 0.9644Epoch 00001: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.1457 - acc: 0.9635 - val_loss: 0.5481 - val_acc: 0.8228
# Epoch 3/50
# 6144/6680 [==========================>...] - ETA: 0s - loss: 0.1319 - acc: 0.9686Epoch 00002: val_loss improved from 0.54494 to 0.51912, saving model to saved_models/weights.best.Resnet50.hdf5
# 6680/6680 [==============================] - 0s - loss: 0.1330 - acc: 0.9684 - val_loss: 0.5191 - val_acc: 0.8371
# Epoch 4/50
# 5120/6680 [=====================>........] - ETA: 0s - loss: 0.1233 - acc: 0.9711Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.1246 - acc: 0.9702 - val_loss: 0.5459 - val_acc: 0.8240
# Epoch 5/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.1179 - acc: 0.9743Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.1156 - acc: 0.9749 - val_loss: 0.5644 - val_acc: 0.8228
# Epoch 6/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.1141 - acc: 0.9719Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.1105 - acc: 0.9746 - val_loss: 0.5383 - val_acc: 0.8180
# Epoch 7/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.1064 - acc: 0.9757Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.1052 - acc: 0.9756 - val_loss: 0.5747 - val_acc: 0.8204
# Epoch 8/50
# 5120/6680 [=====================>........] - ETA: 0s - loss: 0.0911 - acc: 0.9818Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0929 - acc: 0.9807 - val_loss: 0.5466 - val_acc: 0.8335
# Epoch 9/50
# 6144/6680 [==========================>...] - ETA: 0s - loss: 0.0937 - acc: 0.9792Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0931 - acc: 0.9796 - val_loss: 0.5447 - val_acc: 0.8287
# Epoch 10/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0874 - acc: 0.9817Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0877 - acc: 0.9819 - val_loss: 0.5502 - val_acc: 0.8275
# Epoch 11/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0841 - acc: 0.9833Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0834 - acc: 0.9835 - val_loss: 0.5519 - val_acc: 0.8263
# Epoch 12/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0748 - acc: 0.9881Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0739 - acc: 0.9880 - val_loss: 0.5494 - val_acc: 0.8299
# Epoch 13/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0792 - acc: 0.9831Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0761 - acc: 0.9847 - val_loss: 0.5374 - val_acc: 0.8395
# Epoch 14/50
# 6144/6680 [==========================>...] - ETA: 0s - loss: 0.0714 - acc: 0.9847Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0713 - acc: 0.9843 - val_loss: 0.5467 - val_acc: 0.8395
# Epoch 15/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0660 - acc: 0.9886Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0667 - acc: 0.9876 - val_loss: 0.5385 - val_acc: 0.8383
# Epoch 16/50
# 6144/6680 [==========================>...] - ETA: 0s - loss: 0.0642 - acc: 0.9867Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0644 - acc: 0.9870 - val_loss: 0.5471 - val_acc: 0.8383
# Epoch 17/50
# 6144/6680 [==========================>...] - ETA: 0s - loss: 0.0605 - acc: 0.9889Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0627 - acc: 0.9879 - val_loss: 0.5316 - val_acc: 0.8371
# Epoch 18/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0617 - acc: 0.9886Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0618 - acc: 0.9888 - val_loss: 0.5454 - val_acc: 0.8347
# Epoch 19/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0549 - acc: 0.9886Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0563 - acc: 0.9877 - val_loss: 0.5404 - val_acc: 0.8419
# Epoch 20/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0545 - acc: 0.9906Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0547 - acc: 0.9901 - val_loss: 0.5374 - val_acc: 0.8443
# Epoch 21/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0506 - acc: 0.9899Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0506 - acc: 0.9901 - val_loss: 0.5544 - val_acc: 0.8275
# Epoch 22/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0519 - acc: 0.9906Epoch 00021: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0509 - acc: 0.9909 - val_loss: 0.5579 - val_acc: 0.8407
# Epoch 23/50
# 5120/6680 [=====================>........] - ETA: 0s - loss: 0.0466 - acc: 0.9904Epoch 00022: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0479 - acc: 0.9903 - val_loss: 0.5589 - val_acc: 0.8383
# Epoch 24/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0458 - acc: 0.9925Epoch 00023: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0477 - acc: 0.9912 - val_loss: 0.5556 - val_acc: 0.8263
# Epoch 25/50
# 5120/6680 [=====================>........] - ETA: 0s - loss: 0.0423 - acc: 0.9920Epoch 00024: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0459 - acc: 0.9907 - val_loss: 0.5442 - val_acc: 0.8335
# Epoch 26/50
# 5120/6680 [=====================>........] - ETA: 0s - loss: 0.0463 - acc: 0.9902Epoch 00025: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0454 - acc: 0.9909 - val_loss: 0.5592 - val_acc: 0.8359
# Epoch 27/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0421 - acc: 0.9909Epoch 00026: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0436 - acc: 0.9912 - val_loss: 0.5327 - val_acc: 0.8431
# Epoch 28/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0413 - acc: 0.9925Epoch 00027: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0410 - acc: 0.9927 - val_loss: 0.5691 - val_acc: 0.8323
# Epoch 29/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0423 - acc: 0.9913Epoch 00028: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0421 - acc: 0.9913 - val_loss: 0.5434 - val_acc: 0.8443
# Epoch 30/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0386 - acc: 0.9929Epoch 00029: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0381 - acc: 0.9927 - val_loss: 0.5565 - val_acc: 0.8323
# Epoch 31/50
# 5120/6680 [=====================>........] - ETA: 0s - loss: 0.0375 - acc: 0.9920Epoch 00030: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0375 - acc: 0.9922 - val_loss: 0.5677 - val_acc: 0.8419
# Epoch 32/50
# 5120/6680 [=====================>........] - ETA: 0s - loss: 0.0342 - acc: 0.9947Epoch 00031: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0339 - acc: 0.9948 - val_loss: 0.5637 - val_acc: 0.8371
# Epoch 33/50
# 5120/6680 [=====================>........] - ETA: 0s - loss: 0.0356 - acc: 0.9938Epoch 00032: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0364 - acc: 0.9931 - val_loss: 0.5770 - val_acc: 0.8347
# Epoch 34/50
# 5120/6680 [=====================>........] - ETA: 0s - loss: 0.0335 - acc: 0.9924Epoch 00033: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0350 - acc: 0.9921 - val_loss: 0.5579 - val_acc: 0.8419
# Epoch 35/50
# 5120/6680 [=====================>........] - ETA: 0s - loss: 0.0320 - acc: 0.9941Epoch 00034: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0320 - acc: 0.9939 - val_loss: 0.5515 - val_acc: 0.8323
# Epoch 36/50
# 5120/6680 [=====================>........] - ETA: 0s - loss: 0.0360 - acc: 0.9916Epoch 00035: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0358 - acc: 0.9922 - val_loss: 0.5757 - val_acc: 0.8335
# Epoch 37/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0311 - acc: 0.9931Epoch 00036: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0306 - acc: 0.9936 - val_loss: 0.5791 - val_acc: 0.8299
# Epoch 38/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0315 - acc: 0.9943Epoch 00037: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0321 - acc: 0.9939 - val_loss: 0.5683 - val_acc: 0.8359
# Epoch 39/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0328 - acc: 0.9929Epoch 00038: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0314 - acc: 0.9937 - val_loss: 0.5753 - val_acc: 0.8395
# Epoch 40/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0304 - acc: 0.9949Epoch 00039: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0307 - acc: 0.9945 - val_loss: 0.5776 - val_acc: 0.8443
# Epoch 41/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0293 - acc: 0.9945Epoch 00040: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0294 - acc: 0.9945 - val_loss: 0.5842 - val_acc: 0.8299
# Epoch 42/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0266 - acc: 0.9954Epoch 00041: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0265 - acc: 0.9954 - val_loss: 0.5826 - val_acc: 0.8347
# Epoch 43/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0254 - acc: 0.9959Epoch 00042: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0264 - acc: 0.9951 - val_loss: 0.5961 - val_acc: 0.8323
# Epoch 44/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0269 - acc: 0.9949Epoch 00043: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0273 - acc: 0.9943 - val_loss: 0.5882 - val_acc: 0.8335
# Epoch 45/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0304 - acc: 0.9945Epoch 00044: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0299 - acc: 0.9943 - val_loss: 0.5844 - val_acc: 0.8383
# Epoch 46/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0257 - acc: 0.9949Epoch 00045: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0265 - acc: 0.9946 - val_loss: 0.5822 - val_acc: 0.8455
# Epoch 47/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0274 - acc: 0.9947Epoch 00046: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0271 - acc: 0.9948 - val_loss: 0.6059 - val_acc: 0.8359
# Epoch 48/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0251 - acc: 0.9945Epoch 00047: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0260 - acc: 0.9940 - val_loss: 0.5829 - val_acc: 0.8371
# Epoch 49/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0279 - acc: 0.9936Epoch 00048: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0286 - acc: 0.9930 - val_loss: 0.5881 - val_acc: 0.8311
# Epoch 50/50
# 5632/6680 [========================>.....] - ETA: 0s - loss: 0.0241 - acc: 0.9945Epoch 00049: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 0.0231 - acc: 0.9952 - val_loss: 0.6149 - val_acc: 0.8299
# fine tunning Xception
# Train on 6680 samples, validate on 835 samples
# Epoch 1/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.1411 - acc: 0.9706Epoch 00000: val_loss improved from inf to 0.43484, saving model to saved_models/weights.best.Xception.hdf5
# 6680/6680 [==============================] - 1s - loss: 0.1408 - acc: 0.9707 - val_loss: 0.4348 - val_acc: 0.8587
# Epoch 2/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.1268 - acc: 0.9725Epoch 00001: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.1272 - acc: 0.9723 - val_loss: 0.4396 - val_acc: 0.8599
# Epoch 3/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.1201 - acc: 0.9730Epoch 00002: val_loss improved from 0.43484 to 0.43325, saving model to saved_models/weights.best.Xception.hdf5
# 6680/6680 [==============================] - 1s - loss: 0.1199 - acc: 0.9731 - val_loss: 0.4333 - val_acc: 0.8599
# Epoch 4/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.1147 - acc: 0.9754Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.1148 - acc: 0.9753 - val_loss: 0.4348 - val_acc: 0.8647
# Epoch 5/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.1077 - acc: 0.9775Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.1076 - acc: 0.9775 - val_loss: 0.4406 - val_acc: 0.8671
# Epoch 6/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.1034 - acc: 0.9776Epoch 00005: val_loss improved from 0.43325 to 0.42960, saving model to saved_models/weights.best.Xception.hdf5
# 6680/6680 [==============================] - 1s - loss: 0.1032 - acc: 0.9777 - val_loss: 0.4296 - val_acc: 0.8683
# Epoch 7/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0948 - acc: 0.9797Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0947 - acc: 0.9798 - val_loss: 0.4424 - val_acc: 0.8707
# Epoch 8/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0879 - acc: 0.9829Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0879 - acc: 0.9829 - val_loss: 0.4426 - val_acc: 0.8659
# Epoch 9/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0843 - acc: 0.9848Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0843 - acc: 0.9847 - val_loss: 0.4410 - val_acc: 0.8707
# Epoch 10/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0791 - acc: 0.9847Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0792 - acc: 0.9846 - val_loss: 0.4510 - val_acc: 0.8647
# Epoch 11/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0771 - acc: 0.9856Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0771 - acc: 0.9856 - val_loss: 0.4418 - val_acc: 0.8671
# Epoch 12/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0718 - acc: 0.9872Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0718 - acc: 0.9873 - val_loss: 0.4444 - val_acc: 0.8671
# Epoch 13/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0672 - acc: 0.9878Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0671 - acc: 0.9879 - val_loss: 0.4452 - val_acc: 0.8707
# Epoch 14/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0636 - acc: 0.9896Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0636 - acc: 0.9897 - val_loss: 0.4467 - val_acc: 0.8635
# Epoch 15/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0604 - acc: 0.9890Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0605 - acc: 0.9889 - val_loss: 0.4653 - val_acc: 0.8599
# Epoch 16/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0573 - acc: 0.9898Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0573 - acc: 0.9897 - val_loss: 0.4605 - val_acc: 0.8623
# Epoch 17/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0579 - acc: 0.9890Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0579 - acc: 0.9889 - val_loss: 0.4635 - val_acc: 0.8671
# Epoch 18/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0527 - acc: 0.9917Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0528 - acc: 0.9918 - val_loss: 0.4612 - val_acc: 0.8743
# Epoch 19/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0511 - acc: 0.9908Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0513 - acc: 0.9907 - val_loss: 0.4734 - val_acc: 0.8659
# Epoch 20/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0478 - acc: 0.9919Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0479 - acc: 0.9919 - val_loss: 0.4712 - val_acc: 0.8599
# Epoch 21/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0465 - acc: 0.9923Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0466 - acc: 0.9924 - val_loss: 0.4846 - val_acc: 0.8575
# Epoch 22/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0435 - acc: 0.9937Epoch 00021: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0435 - acc: 0.9937 - val_loss: 0.4668 - val_acc: 0.8623
# Epoch 23/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0412 - acc: 0.9946Epoch 00022: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0412 - acc: 0.9946 - val_loss: 0.4826 - val_acc: 0.8623
# Epoch 24/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0399 - acc: 0.9941Epoch 00023: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0400 - acc: 0.9940 - val_loss: 0.4720 - val_acc: 0.8647
# Epoch 25/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0387 - acc: 0.9941Epoch 00024: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0388 - acc: 0.9942 - val_loss: 0.4765 - val_acc: 0.8623
# Epoch 26/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0369 - acc: 0.9944Epoch 00025: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0369 - acc: 0.9945 - val_loss: 0.4811 - val_acc: 0.8587
# Epoch 27/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0344 - acc: 0.9952Epoch 00026: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0346 - acc: 0.9951 - val_loss: 0.4836 - val_acc: 0.8611
# Epoch 28/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0342 - acc: 0.9958Epoch 00027: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0342 - acc: 0.9958 - val_loss: 0.4884 - val_acc: 0.8623
# Epoch 29/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0321 - acc: 0.9965Epoch 00028: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0320 - acc: 0.9966 - val_loss: 0.4810 - val_acc: 0.8611
# Epoch 30/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0319 - acc: 0.9953Epoch 00029: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0319 - acc: 0.9954 - val_loss: 0.4875 - val_acc: 0.8611
# Epoch 31/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0317 - acc: 0.9958Epoch 00030: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0317 - acc: 0.9958 - val_loss: 0.5084 - val_acc: 0.8623
# Epoch 32/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0284 - acc: 0.9956Epoch 00031: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0284 - acc: 0.9957 - val_loss: 0.4997 - val_acc: 0.8575
# Epoch 33/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0284 - acc: 0.9964Epoch 00032: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0287 - acc: 0.9961 - val_loss: 0.4962 - val_acc: 0.8623
# Epoch 34/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0270 - acc: 0.9970Epoch 00033: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0270 - acc: 0.9970 - val_loss: 0.4981 - val_acc: 0.8695
# Epoch 35/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0260 - acc: 0.9970Epoch 00034: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0259 - acc: 0.9970 - val_loss: 0.5146 - val_acc: 0.8527
# Epoch 36/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0258 - acc: 0.9967Epoch 00035: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0258 - acc: 0.9967 - val_loss: 0.5117 - val_acc: 0.8611
# Epoch 37/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0247 - acc: 0.9965Epoch 00036: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0250 - acc: 0.9964 - val_loss: 0.5108 - val_acc: 0.8599
# Epoch 38/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0229 - acc: 0.9979Epoch 00037: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0229 - acc: 0.9979 - val_loss: 0.5114 - val_acc: 0.8659
# Epoch 39/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0222 - acc: 0.9979Epoch 00038: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0222 - acc: 0.9979 - val_loss: 0.5156 - val_acc: 0.8683
# Epoch 40/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0223 - acc: 0.9974Epoch 00039: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0223 - acc: 0.9975 - val_loss: 0.5246 - val_acc: 0.8599
# Epoch 41/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0212 - acc: 0.9971Epoch 00040: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0213 - acc: 0.9972 - val_loss: 0.5208 - val_acc: 0.8659
# Epoch 42/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0206 - acc: 0.9970Epoch 00041: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0206 - acc: 0.9970 - val_loss: 0.5293 - val_acc: 0.8575
# Epoch 43/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0200 - acc: 0.9980Epoch 00042: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0199 - acc: 0.9981 - val_loss: 0.5221 - val_acc: 0.8695
# Epoch 44/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0193 - acc: 0.9977Epoch 00043: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0193 - acc: 0.9978 - val_loss: 0.5328 - val_acc: 0.8659
# Epoch 45/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0188 - acc: 0.9977Epoch 00044: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0190 - acc: 0.9978 - val_loss: 0.5231 - val_acc: 0.8671
# Epoch 46/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0182 - acc: 0.9973Epoch 00045: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0182 - acc: 0.9973 - val_loss: 0.5224 - val_acc: 0.8623
# Epoch 47/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0187 - acc: 0.9976Epoch 00046: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0187 - acc: 0.9976 - val_loss: 0.5233 - val_acc: 0.8623
# Epoch 48/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0169 - acc: 0.9982Epoch 00047: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0169 - acc: 0.9982 - val_loss: 0.5273 - val_acc: 0.8635
# Epoch 49/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0167 - acc: 0.9977Epoch 00048: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0167 - acc: 0.9978 - val_loss: 0.5402 - val_acc: 0.8635
# Epoch 50/50
# 6656/6680 [============================>.] - ETA: 0s - loss: 0.0169 - acc: 0.9976Epoch 00049: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 0.0168 - acc: 0.9976 - val_loss: 0.5432 - val_acc: 0.8599

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
loaded_models = {}
for network_name in networks:
    print(network_name)
    my_models[network].load_weights('saved_models/weights.best.{}.hdf5'.format(network_name))
# Out:
# Resnet50
# Xception

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.

# get index of predicted dog breed for each image in test set
for network_name in networks:
    predictions = [np.argmax(my_models[network_name].predict(np.expand_dims(feature, axis=0))) for feature in test[network_name]]
    # report test accuracy
    test_accuracy = 100*np.sum(np.array(predictions)==np.argmax(test_targets, axis=1))/len(predictions)
    print('Test accuracy for model based on {}: %.4f%%'.format(network_name) % test_accuracy)
# Out:
# Test accuracy for model based on Resnet50: 83.2536%
# Test accuracy for model based on Xception: 86.4833%

# %%
best_model_name = 'Xception'

# %% [markdown]
# Xception is the winner in term of accuracy on our dataset, Resnet50 was also really impressive here. The results are really better than the previous accuracy with our from scratch model. Indeed the two pre-trained models have a lot more of layers, and moreover are trained on a huge amount of data. Moreover we didn't retrain the convolutional layers thus limiting the overfitting on the training data.

# %%
# TODO: compare results with results on same dataset https://web.stanford.edu/class/cs231a/prev_projects_2016/output (1).pdf

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
print(networks)
model_name_to_use = 'Xception'
# Out:
# ['Resnet50', 'Xception']

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.
from extract_bottleneck_features import extract_Resnet50, extract_Xception, extract_VGG19, extract_InceptionV3
# we use a simple dictionary to associate each extract/preprocess function to each network name
extract_functions = {'Resnet50':extract_Resnet50, 'Xception': extract_Xception, 'VGG19': extract_VGG19, 'InceptionV3': extract_InceptionV3}
# extract bottleneck features
extract_function = extract_functions[model_name_to_use]
model = my_models[model_name_to_use]
#bottleneck_feature = extract_function(path_to_tensor(img_path))


def predict_breed(img_path, model_name_to_use, threshold_for_second_breed=0.4):
    """
    Return best breed or the two best breed
    
    If the dog seems to be a merge of two breeds we return the two breeds
    """
    # extract bottleneck features
    extract_function = extract_functions[model_name_to_use]
    model = my_models[model_name_to_use]
    bottleneck_feature = extract_function(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = model.predict(bottleneck_feature)[0]
    # return dog breed that is predicted by the model
    # TODO: laurent: return the 2 best breed if we have 51, 49 score for instance, because it's certainly a dog bastard
    sorted_index = np.argsort(-predicted_vector)
    if predicted_vector[sorted_index[1]] > threshold_for_second_breed:
        return [dog_names[sorted_index[0]], dog_names[sorted_index[1]]]
    return [dog_names[sorted_index[0]]]

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

import cv2
from matplotlib import pyplot as plt

def breed_prediction(image_path):
    """
    Try to find the breed to associate with the image
    
    if a dog or a human is detected we try to match to the closest breed
    otherwise we don't compute the breed
    
    return: (detected_kind, associated_breed)
    """
    if dog_detector(image_path):
        return ('dog', predict_breed(image_path, best_model_name))
    if face_detector(image_path):
        return ('human', predict_breed(image_path, best_model_name))
    return ('unknown', None)

def ihm_breed_prediction(image_path, display=True):
    object_kind, breeds = breed_prediction(image_path)
    img = cv2.imread(image_path)
    rgb_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    output_breed_string = ''
    if len(breeds) > 1:
        output_breed_string = 'a mixture between {}'.format('and '.join(breeds))
    if len(breeds) == 1:
        output_breed_string = 'a {}'.format(breeds[0])
        
    output_string = 'Fail to detect human or dog'
    if object_kind == 'dog':
        output_string = 'This dog seems to be {}  (on the right an example of this breed from the dataset)'.format(output_breed_string)
    if object_kind == 'human':
        output_string = 'This human looks like {}'.format(output_breed_string)
        
    if len(breeds) == 1:
        dog_class_image = cv2.imread(dogs_preview[breeds[0]])
    if len(breeds) == 2:
        # we handle only 2 class here
        img1 = cv2.imread(dogs_preview[breeds[0]])
        img2 = cv2.imread(dogs_preview[breeds[1]])
        width, height = img1.shape[1], img1.shape[0]
        img2 = cv2.resize(img2, (width, height))
        vis = np.concatenate((img1, img2), axis=1)
        dog_class_image = cv2.resize(vis, (width, height))
        
    dog_class_image = cv2.cvtColor(dog_class_image, cv2.COLOR_BGR2RGB)

    if display:
        print(output_string)
        fig = plt.figure()
        a=fig.add_subplot(1,2,1)
        plt.imshow(rgb_image)
        plt.axis('off')

            
        #plt.title(output_string)
        a=fig.add_subplot(1,2,2)
        plt.imshow(dog_class_image)
        plt.axis('off')
        plt.show()
    
    return output_string, rgb_image, dog_class_image

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__

# %% [markdown]
# The outputs are really good in my point of view (when predicting breed for a dog photo), the associated breed seems always to be quite similar to the dog.
#
# Points for improvements:
#
# - increase training dataset size to be able to have a better accuracy
# - reducce computation speed (for example using mobilenet network)
# - use boosting to increase accuracy

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

import glob

my_dog_files = glob.glob('my_images/dogs/*')

for image_fname in my_dog_files:
    print(image_fname)
    ihm_breed_prediction(image_fname)
# Out:
# my_images/dogs/Curly-coated_retriever_03896.jpg
# This dog seems to be a Curly-coated_retriever  (on the right an example of this breed from the dataset)
# my_images/dogs/Lundehund-2003.jpg
# This dog seems to be a Norwegian_lundehund  (on the right an example of this breed from the dataset)
# my_images/dogs/labrador_1.jpg
# This dog seems to be a Labrador_retriever  (on the right an example of this breed from the dataset)
# my_images/dogs/labri_des_pyrennee
# This dog seems to be a Havanese  (on the right an example of this breed from the dataset)

# %%
my_human_files = glob.glob('my_images/humans/*')
for image_fname in my_human_files:
    print(image_fname)
    ihm_breed_prediction(image_fname)
# Out:
# my_images/humans/stark.jpg
# This human looks like a Poodle
# my_images/humans/brad_pit.jpg
# This human looks like a Dachshund
# my_images/humans/elon_musk.jpg
# This human looks like a Pekingese
# my_images/humans/lanister1.jpg
# This human looks like a Petit_basset_griffon_vendeen
# my_images/humans/audreyhepburn.jpg
# This human looks like a Poodle
